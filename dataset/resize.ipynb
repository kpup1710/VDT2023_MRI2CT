# %%
#!/usr/bin/python
from PIL import Image
import os, sys

path = "C:\\Users\\RedmiBook\\HUST\\Documents\\Studying\\VT_DSAI\\mini_project\\code\\MRI2CT\\dataset\\mri2ct\\MRI"
dirs = os.listdir( path )
out_dir = 'C:\\Users\\RedmiBook\\HUST\\Documents\\Studying\\VT_DSAI\\mini_project\\code\\MRI2CT\\dataset\\mri2ct\\MRI_resized'
print(dirs)
def resize():
    for item in dirs:
        if os.path.isfile(path+ '/'+item):
            print('hehe')
            im = Image.open(path+'/'+item)
            f, e = os.path.splitext(out_dir+'/'+item)
    
            imResize = im.resize((200,200), Image.ANTIALIAS)
            imResize.save(out_dir + f'{f}.png', 'PNG', quality=90)

resize()
# Out:
# ['mri1.jpg', 'mri1001.jpg', 'mri1002.jpg', 'mri1003.jpg', 'mri1004.jpg', 'mri1005.jpg', 'mri1006.jpg', 'mri1007.jpg', 'mri101.jpg', 'mri1011.jpg', 'mri1012.jpg', 'mri1013.jpg', 'mri1014.jpg', 'mri1015.jpg', 'mri1016.jpg', 'mri1017.jpg', 'mri102.jpg', 'mri1021.jpg', 'mri1022.jpg', 'mri1023.jpg', 'mri1024.jpg', 'mri1025.jpg', 'mri1026.jpg', 'mri1027.jpg', 'mri103.jpg', 'mri1031.jpg', 'mri1032.jpg', 'mri1033.jpg', 'mri1034.jpg', 'mri1035.jpg', 'mri1036.jpg', 'mri1037.jpg', 'mri104.jpg', 'mri1041.jpg', 'mri1042.jpg', 'mri1043.jpg', 'mri1044.jpg', 'mri1045.jpg', 'mri1046.jpg', 'mri1047.jpg', 'mri105.jpg', 'mri1051.jpg', 'mri1052.jpg', 'mri1053.jpg', 'mri1054.jpg', 'mri1055.jpg', 'mri1056.jpg', 'mri1057.jpg', 'mri106.jpg', 'mri1061.jpg', 'mri1062.jpg', 'mri1063.jpg', 'mri1064.jpg', 'mri1065.jpg', 'mri1066.jpg', 'mri1067.jpg', 'mri107.jpg', 'mri1071.jpg', 'mri1072.jpg', 'mri1073.jpg', 'mri1074.jpg', 'mri1075.jpg', 'mri1076.jpg', 'mri1077.jpg', 'mri1081.jpg', 'mri1082.jpg', 'mri1083.jpg', 'm
# ...
