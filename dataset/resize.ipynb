# %%
#!/usr/bin/python
from PIL import Image
import os, sys

path = "C:\\Users\\RedmiBook\\HUST\\Documents\\Studying\\VT_DSAI\\mini_project\\code\\MRI2CT\\dataset\\test\\MRI"
dirs = os.listdir( path )
out_dir = 'C:\\Users\\RedmiBook\\HUST\\Documents\\Studying\\VT_DSAI\\mini_project\\code\\MRI2CT\\dataset\\test\\MRI_resized\\'
print(dirs)
def resize():
    for item in dirs:
        if os.path.isfile(path+ '/'+item):
            print('hehe')
            im = Image.open(path+'/'+item)
            f, e = os.path.splitext(path+'/'+item)
    
            imResize = im.resize((512,512), Image.LANCZOS )
            imResize.save(out_dir + item.strip('.jpg')+'.png', 'PNG', quality=90)

resize()
# Out:
# ['mri10.jpg', 'mri100.jpg', 'mri1000.jpg', 'mri1008.jpg', 'mri1009.jpg', 'mri1010.jpg', 'mri1018.jpg', 'mri1019.jpg', 'mri1020.jpg', 'mri1028.jpg', 'mri1029.jpg', 'mri1030.jpg', 'mri1038.jpg', 'mri1039.jpg', 'mri1040.jpg', 'mri1048.jpg', 'mri1049.jpg', 'mri1050.jpg', 'mri1058.jpg', 'mri1059.jpg', 'mri1060.jpg', 'mri1068.jpg', 'mri1069.jpg', 'mri1070.jpg', 'mri1078.jpg', 'mri1079.jpg', 'mri108.jpg', 'mri1080.jpg', 'mri1088.jpg', 'mri1089.jpg', 'mri109.jpg', 'mri1090.jpg', 'mri1098.jpg', 'mri1099.jpg', 'mri110.jpg', 'mri1100.jpg', 'mri1108.jpg', 'mri1109.jpg', 'mri1110.jpg', 'mri1118.jpg', 'mri1119.jpg', 'mri1120.jpg', 'mri1128.jpg', 'mri1129.jpg', 'mri1130.jpg', 'mri1138.jpg', 'mri1139.jpg', 'mri1140.jpg', 'mri1148.jpg', 'mri1149.jpg', 'mri1150.jpg', 'mri1158.jpg', 'mri1159.jpg', 'mri1160.jpg', 'mri1168.jpg', 'mri1169.jpg', 'mri1170.jpg', 'mri1178.jpg', 'mri1179.jpg', 'mri118.jpg', 'mri1180.jpg', 'mri1188.jpg', 'mri1189.jpg', 'mri119.jpg', 'mri1190.jpg', 'mri1198.jpg', 'mri1199.jpg', 
# ...
